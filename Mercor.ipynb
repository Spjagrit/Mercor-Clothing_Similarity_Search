26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
product_list.remove("https://amazon.inhttps://aax-eu.amazon.in/x/c/RBVFAzDHzGGTkYlave7q-NAAAAGIRCpubAMAAAH2AQBvbm9fdHhuX2JpZDEgICBvbm9fdHhuX2ltcDEgICDYiGeC/https://www.amazon.in/JONELIWIS-Regular-Fit-Sleeve-Casual-Sleeves/dp/B0BQM7MBDM/ref=sxin_19_sbv_search_btf?content-id=amzn1.sym.59f7581a-8b36-4cad-8093-b8a6e1e96987%3Aamzn1.sym.59f7581a-8b36-4cad-8093-b8a6e1e96987&crid=1WVVQ3KF0WYC5&cv_ct_cx=shirt&keywords=shirt&pd_rd_i=B0BQM7MBDM&pd_rd_r=01180176-d673-4c7c-aa39-3d9316c253bb&pd_rd_w=GvcST&pd_rd_wg=GtGfR&pf_rd_p=59f7581a-8b36-4cad-8093-b8a6e1e96987&pf_rd_r=57JVFFJK8VRER5A5MQRM&qid=1684770811&sbo=RZvfv%2F%2FHxDF%2BO5021pAnSA%3D%3D&sprefix=%2Caps%2C208&sr=1-1-9131241a-a358-4619-a7b8-0f5a65d91d81")
product_list
# Out:
# ['https://amazon.in/sspa/click?ie=UTF8&spc=MTo0NjMzMjc3ODExMjk1MjU4OjE2ODQ3NzA4MTE6c3BfYXRmOjIwMTQ5ODk1MTk4MDk4OjowOjo&url=%2FKINGDOM-WHITE-Relajarse-Sleeve-Spanish%2Fdp%2FB0BRNGKJ9M%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1WVVQ3KF0WYC5%26keywords%3Dshirt%26qid%3D1684770811%26sprefix%3D%252Caps%252C208%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://amazon.in/sspa/click?ie=UTF8&spc=MTo0NjMzMjc3ODExMjk1MjU4OjE2ODQ3NzA4MTE6c3BfYXRmOjIwMTAzOTQ3Njc5MTk4OjowOjo&url=%2FAmazon-Brand-Shields-Checkered-SS20-HS-RR-01-J_Red-Black%2Fdp%2FB084MZT65K%2Fref%3Dsr_1_2_sspa%3Fcrid%3D1WVVQ3KF0WYC5%26keywords%3Dshirt%26qid%3D1684770811%26sprefix%3D%252Caps%252C208%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
product_l1=0
new_webpage=0
new_soup=0
for i in range(len(product_list)):
  product_l1=product_list[i]
  new_webpage=requests.get(product_l1, headers=HEADERS)
  new_webpage
  new_soup=BeautifulSoup(new_webpage.content, "html.parser")
  print(new_soup.find("h1", attrs={"id":'title'}).text.strip())
# Out:
# KINGDOM OF WHITE Relajarse Half Sleeve Casual Shirt for Men with Spanish Collar | 100% Linen | Casual Wear Shirts for Men | White Color | Plain Weave
# Amazon Brand - House & Shields Men's Regular Casual Shirt
# Ben Martin Men's Classic Collar Slim Fit Cotton Casual Full Sleeve Shirt
# ENDLESSTRENDZ Men's 100% Cotton Check Regular Fit Casual Shirt - Pure Soft Cotton Checked Shirts for Men Stylish/Trendy Full Sleeve Shirt for Office, Party & Outing
# Dennis Lingo Men's Solid Slim Fit Cotton Casual Shirt with Spread Collar & Full Sleeves
# Lymio Casual Shirt for Men|| Shirt for Men|| Men Stylish Shirt || Men Printed Shirt (Mistry)
# Peppyzone Men's Regular Fit Checked Casual Shirt
# Van Heusen Sport Men Casual Shirt
# Amazon Brand - Inkast Denim Co. Men's Slim Fit Casual Shirt
# Amazon Brand - Symbol Men Formal Shirt
# Dennis Lingo Men's Cotton Buffalo Check Slim Fit Casual Shirt with Pocket, Full Sleeve Shirt for Formal & Casual Wear
# ...

# %%
product_l1=0
new_webpage=0
new_soup=0
l1=[]
for i in range(len(product_list)):
  product_l1=product_list[i]
  new_webpage=requests.get(product_l1, headers=HEADERS)
  new_webpage
  new_soup=BeautifulSoup(new_webpage.content, "html.parser")
  l1.append(new_soup.find("h1", attrs={"id":'title'}).text.strip())

# %%
for i in range(len(l1)):
  print(l1[i])
# Out:
# KINGDOM OF WHITE Relajarse Half Sleeve Casual Shirt for Men with Spanish Collar | 100% Linen | Casual Wear Shirts for Men | White Color | Plain Weave
# Amazon Brand - House & Shields Men's Regular Casual Shirt
# Ben Martin Men's Classic Collar Slim Fit Cotton Casual Full Sleeve Shirt
# ENDLESSTRENDZ Men's 100% Cotton Check Regular Fit Casual Shirt - Pure Soft Cotton Checked Shirts for Men Stylish/Trendy Full Sleeve Shirt for Office, Party & Outing
# Dennis Lingo Men's Solid Slim Fit Cotton Casual Shirt with Spread Collar & Full Sleeves
# Lymio Casual Shirt for Men|| Shirt for Men|| Men Stylish Shirt || Men Printed Shirt (Mistry)
# Peppyzone Men's Regular Fit Checked Casual Shirt
# Van Heusen Sport Men Casual Shirt
# Amazon Brand - Inkast Denim Co. Men's Slim Fit Casual Shirt
# Amazon Brand - Symbol Men Formal Shirt
# Dennis Lingo Men's Cotton Buffalo Check Slim Fit Casual Shirt with Pocket, Full Sleeve Shirt for Formal & Casual Wear
# ...

# %%
new_webpage1=requests.get(product_list[0], headers=HEADERS)
new_webpage1
new_soup1=BeautifulSoup(new_webpage1.content, "html.parser")
print(new_soup1.find("span", attrs={"class": "a-offscreen"}).text.strip())
# Out:
# ₹2,974.00

# %%
product_l2=0
new_webpage1=0
new_soup1=0
l2=[]
for i in range(len(product_list)):
  product_l2=product_list[i]
  new_webpage1=requests.get(product_l2, headers=HEADERS)
  new_webpage1
  new_soup1=BeautifulSoup(new_webpage1.content, "html.parser")
  l2.append(new_soup1.find("span", attrs={"class": "a-offscreen"}).text.strip())

# %%
product_l3=0
new_webpage2=0
new_soup2=0
l3=[]
for i in range(len(product_list)):
  product_l3=product_list[i]
  new_webpage2=requests.get(product_l3, headers=HEADERS)
  new_webpage2
  new_soup2=BeautifulSoup(new_webpage2.content, "html.parser")
  l3.append(new_soup1.find("span", attrs={"class":'a-icon-alt'}).text)

# %%
import pandas as pd
data = {
    'Description': l1,
    'Rating': l3
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                          Description              Rating
# 0  KINGDOM OF WHITE Relajarse Half Sleeve Casual ...  3.8 out of 5 stars
# 1  Amazon Brand - House & Shields Men's Regular C...  3.8 out of 5 stars
# 2  Ben Martin Men's Classic Collar Slim Fit Cotto...  3.8 out of 5 stars
# 3  ENDLESSTRENDZ Men's 100% Cotton Check Regular ...  3.8 out of 5 stars
# 4  Dennis Lingo Men's Solid Slim Fit Cotton Casua...  3.8 out of 5 stars

# %%
# Import libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Convert text data to TF-IDF vectors
X = vectorizer.fit_transform(preprocessed_data)

# Compute cosine similarities between all pairs of vectors
cosine_similarities = cosine_similarity(X, X)

# %%
# Define function to return ranked results
def get_ranked_results(query):
    # Convert query to TF-IDF vector
    query_vector = vectorizer.transform([query])

    # Find cosine similarities between query and all items in dataset
    similarities = cosine_similarity(query_vector, X)

    # Rank items by similarity
    ranked_results = similarities.argsort()[::-1]

    return ranked_results

# Get ranked results for query "black dress"
ranked_results = get_ranked_results("black dress")

# Print top 5 results
for i in range(5):
    print(item_descriptions[ranked_results[i]])

# %%
# Import libraries
from google.cloud import functions

# Define function to be deployed
def get_ranked_results(query):
    # Convert query to TF-IDF vector
    query_vector = vectorizer.transform([query])

    # Find cosine similarities between query and all items in dataset
    similarities = cosine_similarity(query_vector, X)

    # Rank items by similarity
    ranked_results = similarities.argsort()[::-1]

    return ranked_results

# Deploy function
functions.Function(
    name="get_ranked_results",
    entry_point="get_ranked_results",
    runtime="python37",
)
